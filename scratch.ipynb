# %%
import torch
import matplotlib.pyplot as plt

# %%
g = torch.load('graphs/jan2019_russia-txt.pt', weights_only=False)
ts = ((g.ts-g.ts.min()) / (60*60*24*7)).int()
# Out:
# tensor([  0,   0,   0,  ..., 388, 388, 388], dtype=torch.int32)

# %%
plt.plot(torch.arange(ts.size(0)), ts)
